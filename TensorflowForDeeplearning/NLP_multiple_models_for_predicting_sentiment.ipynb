# %% [markdown]
# # Using LSTMs, CNNs, GRUs with a larger dataset

# %% [markdown]
# you use different kinds of layers to see how they affect the model.
#
# You will use the glue/sst2 dataset, which is available through tensorflow_datasets.
#
# The General Language Understanding Evaluation (GLUE) benchmark (https://gluebenchmark.com/) is a collection of resources for training, evaluating, and analyzing natural language understanding systems.
#
# These resources include the Stanford Sentiment Treebank (SST) dataset that consists of sentences from movie reviews and human annotations of their sentiment. This colab uses version 2 of the SST dataset.
#
# The splits are:
#
# *   train	67,349
# *   validation	872
#
#
# and the column headings are:
#
# *   sentence
# *   label
#
#
# For more information about the dataset, see [https://www.tensorflow.org/datasets/catalog/glue#gluesst2](https://www.tensorflow.org/datasets/catalog/glue#gluesst2)

# %%
import tensorflow as tf
import tensorflow_datasets as tfds

import numpy as np

# %% [markdown]
# # Get the dataset

# %%
# Get the dataset.
# It has 70000 items, so might take a while to download
dataset, info = tfds.load('glue/sst2', with_info=True)
print(info.features)
print(info.features["label"].num_classes)
print(info.features["label"].names)
# Out:
# FeaturesDict({
#     'idx': int32,
#     'label': ClassLabel(shape=(), dtype=int64, num_classes=2),
#     'sentence': Text(shape=(), dtype=string),
# })
# 2
# ['negative', 'positive']

# %%
# Get the training and validation datasets
dataset_train, dataset_validation = dataset['train'], dataset['validation']
dataset_train
# Out:
# <_PrefetchDataset element_spec={'idx': TensorSpec(shape=(), dtype=tf.int32, name=None), 'label': TensorSpec(shape=(), dtype=tf.int64, name=None), 'sentence': TensorSpec(shape=(), dtype=tf.string, name=None)}>

# %%
# Print some of the entries
for example in dataset_train.take(2):
  review, label = example["sentence"], example["label"]
  print("Review:", review)
  print("Label: %d \n" % label.numpy())
# Out:
# Review: tf.Tensor(b'for the uninitiated plays better on video with the sound ', shape=(), dtype=string)
# Label: 0
#
# Review: tf.Tensor(b'like a giant commercial for universal studios , where much of the action takes place ', shape=(), dtype=string)
# Label: 0

# %%
# Get the sentences and the labels
# for both the training and the validation sets
training_reviews = []
training_labels = []

validation_reviews = []
validation_labels = []

# The dataset has 67,000 training entries, but that's a lot to process here!

# If you want to take the entire dataset: WARNING: takes longer!!
# for item in dataset_train.take(-1):

# Take 10,000 reviews
for item in dataset_train.take(10000):
  review, label = item["sentence"], item["label"]
  training_reviews.append(str(review.numpy()))
  training_labels.append(label.numpy())

print ("\nNumber of training reviews is: ", len(training_reviews))

# print some of the reviews and labels
for i in range(0, 2):
  print (training_reviews[i])
  print (training_labels[i])

# Get the validation data
# there's only about 800 items, so take them all
for item in dataset_validation.take(-1):
  review, label = item["sentence"], item["label"]
  validation_reviews.append(str(review.numpy()))
  validation_labels.append(label.numpy())

print ("\nNumber of validation reviews is: ", len(validation_reviews))

# Print some of the validation reviews and labels
for i in range(0, 2):
  print (validation_reviews[i])
  print (validation_labels[i])
# Out:
# Number of training reviews is:  10000
# b'for the uninitiated plays better on video with the sound '
# 0
# b'like a giant commercial for universal studios , where much of the action takes place '
# 0
#
# Number of validation reviews is:  872
# b'a valueless kiddie paean to pro basketball underwritten by the nba . '
# 0
# b"featuring a dangerously seductive performance from the great daniel auteuil , `` sade '' covers the same period as kaufmann 's `` quills '' with more unsettlingly realistic results . "
# 1

# %% [markdown]
# # Tokenize the words and sequence the sentences

# %%
# There's a total of 21224 words in the reviews
# but many of them are irrelevant like with, it, of, on.
# If we take a subset of the training data, then the vocab
# will be smaller.

# A reasonable review might have about 50 words or so,
# so we can set max_length to 50 (but feel free to change it as you like)

vocab_size = 4000
embedding_dim = 16
max_length = 50
trunc_type='post'
pad_type='post'
oov_tok = "<OOV>"

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_reviews)
word_index = tokenizer.word_index

# %% [markdown]
# # Pad the sequences

# %%
# Pad the sequences so that they are all the same length
training_sequences = tokenizer.texts_to_sequences(training_reviews)
training_padded = pad_sequences(training_sequences,maxlen=max_length,
                                truncating=trunc_type, padding=pad_type)

validation_sequences = tokenizer.texts_to_sequences(validation_reviews)
validation_padded = pad_sequences(validation_sequences,maxlen=max_length)

training_labels_final = np.array(training_labels)
validation_labels_final = np.array(validation_labels)

# %% [markdown]
# # Create the model using an Embedding

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 50, 16)            64000
#
#  global_average_pooling1d_1   (None, 16)               0
#  (GlobalAveragePooling1D)
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 64,017
# Trainable params: 64,017
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train the model

# %%
num_epochs = 20
history = model.fit(training_padded, training_labels_final, epochs=num_epochs,
                    validation_data=(validation_padded, validation_labels_final))
# Out:
# Epoch 1/20
# 313/313 [==============================] - 16s 50ms/step - loss: 0.6835 - accuracy: 0.5554 - val_loss: 0.6889 - val_accuracy: 0.5126
# Epoch 2/20
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6714 - accuracy: 0.5746 - val_loss: 0.6705 - val_accuracy: 0.6089
# Epoch 3/20
# 313/313 [==============================] - 3s 10ms/step - loss: 0.6518 - accuracy: 0.6227 - val_loss: 0.6473 - val_accuracy: 0.6330
# Epoch 4/20
# 313/313 [==============================] - 2s 7ms/step - loss: 0.6233 - accuracy: 0.6702 - val_loss: 0.6156 - val_accuracy: 0.6881
# Epoch 5/20
# 313/313 [==============================] - 2s 8ms/step - loss: 0.5904 - accuracy: 0.7094 - val_loss: 0.5847 - val_accuracy: 0.7122
# Epoch 6/20
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5572 - accuracy: 0.7397 - val_loss: 0.5556 - val_accuracy: 0.7351
# Epoch 7/20
# 313/313 [==============================] - 2s 6ms/step - loss: 0.5254 - accuracy: 0.7698 - val_loss: 0.5354 - val_accuracy: 0.7489
# Epoch 8/20
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4967 - accuracy: 0.7897 - val_loss: 0.5167 - val_accuracy: 0.7580
# Epoch 9/20
# 313/313 [==============================] - 2s 5ms/step - loss: 0.4705 - accuracy: 0.8071 - val_loss: 0.5038 - val_accuracy: 0.7592
# Epoch 10/20
# 313/313 [==============================] - 1s 5ms/step - loss: 0.4474 - accuracy: 0.8199 - val_loss: 0.4942 - val_accuracy: 0.7580
# Epoch 11/20
# 313/313 [==============================] - 2s 5ms/step - loss: 0.4270 - accuracy: 0.8262 - val_loss: 0.4892 - val_accuracy: 0.7615
# Epoch 12/20
# 313/313 [==============================] - 2s 5ms/step - loss: 0.4082 - accuracy: 0.8360 - val_loss: 0.4853 - val_accuracy: 0.7638
# Epoch 13/20
# 313/313 [==============================] - 2s 5ms/step - loss: 0.3907 - accuracy: 0.8411 - val_loss: 0.4833 - val_accuracy: 0.7638
# Epoch 14/20
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3765 - accuracy: 0.8474 - val_loss: 0.4838 - val_accuracy: 0.7683
# Epoch 15/20
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3624 - accuracy: 0.8540 - val_loss: 0.4867 - val_accuracy: 0.7718
# Epoch 16/20
# 313/313 [==============================] - 1s 5ms/step - loss: 0.3498 - accuracy: 0.8569 - val_loss: 0.4891 - val_accuracy: 0.7729
# Epoch 17/20
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3385 - accuracy: 0.8611 - val_loss: 0.4950 - val_accuracy: 0.7764
# Epoch 18/20
# 313/313 [==============================] - 1s 5ms/step - loss: 0.3278 - accuracy: 0.8652 - val_loss: 0.5014 - val_accuracy: 0.7718
# Epoch 19/20
# 313/313 [==============================] - 2s 5ms/step - loss: 0.3180 - accuracy: 0.8681 - val_loss: 0.5089 - val_accuracy: 0.7683
# Epoch 20/20
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3093 - accuracy: 0.8688 - val_loss: 0.5171 - val_accuracy: 0.7626

# %% [markdown]
# # Plot the accurracy and loss

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %% [markdown]
# # Write a function to predict the sentiment of reviews

# %%
# Write some new reviews

review1 = """I loved this movie"""

review2 = """that was the worst movie I've ever seen"""

review3 = """too much violence even for a Bond film"""

review4 = """a captivating recounting of a cherished myth"""

new_reviews = [review1, review2, review3, review4]

# %%
# Define a function to prepare the new reviews for use with a model
# and then use the model to predict the sentiment of the new reviews

def predict_review(model, reviews):
  # Create the sequences
  padding_type='post'
  sample_sequences = tokenizer.texts_to_sequences(reviews)
  reviews_padded = pad_sequences(sample_sequences, padding=padding_type,
                                 maxlen=max_length)
  classes = model.predict(reviews_padded)
  for x in range(len(reviews_padded)):
    print(reviews[x])
    print(classes[x])
    print('\n')

predict_review(model, new_reviews)
# Out:
# 1/1 [==============================] - 0s 80ms/step
# I loved this movie
# [0.3941081]
#
#
# that was the worst movie I've ever seen
# [0.11844173]
#
#
# too much violence even for a Bond film
# [0.0325942]
#
#
# a captivating recounting of a cherished myth
# [0.6168419]

# %% [markdown]
# # Define a function to train and show the results of models with different layers

# %%
def fit_model_and_show_results (model, reviews):
  model.summary()
  history = model.fit(training_padded, training_labels_final, epochs=num_epochs,
                      validation_data=(validation_padded, validation_labels_final))
  plot_graphs(history, "accuracy")
  plot_graphs(history, "loss")
  predict_review(model, reviews)

# %% [markdown]
# # Use a CNN

# %%
num_epochs = 30

model_cnn = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Conv1D(16, 5, activation='relu'),
    tf.keras.layers.GlobalMaxPooling1D(),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Default learning rate for the Adam optimizer is 0.001
# Let's slow down the learning rate by 10.
learning_rate = 0.0001
model_cnn.compile(loss='binary_crossentropy',
                  optimizer=tf.keras.optimizers.Adam(learning_rate),
                  metrics=['accuracy'])

fit_model_and_show_results(model_cnn, new_reviews)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 50, 16)            64000
#
#  conv1d (Conv1D)             (None, 46, 16)            1296
#
#  global_max_pooling1d (Globa  (None, 16)               0
#  lMaxPooling1D)
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 65,313
# Trainable params: 65,313
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 313/313 [==============================] - 23s 55ms/step - loss: 0.6883 - accuracy: 0.5590 - val_loss: 0.6945 - val_accuracy: 0.5092
# Epoch 2/30
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6844 - accuracy: 0.5590 - val_loss: 0.6945 - val_accuracy: 0.5092
# Epoch 3/30
# 313/313 [==============================] - 2s 8ms/step - loss: 0.6819 - accuracy: 0.5590 - val_loss: 0.6928 - val_accuracy: 0.5092
# Epoch 4/30
# 313/313 [==============================] - 3s 11ms/step - loss: 0.6784 - accuracy: 0.5590 - val_loss: 0.6894 - val_accuracy: 0.5092
# Epoch 5/30
# 313/313 [==============================] - 3s 11ms/step - loss: 0.6726 - accuracy: 0.5594 - val_loss: 0.6835 - val_accuracy: 0.5103
# Epoch 6/30
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6625 - accuracy: 0.5692 - val_loss: 0.6724 - val_accuracy: 0.5447
# Epoch 7/30
# 313/313 [==============================] - 2s 8ms/step - loss: 0.6453 - accuracy: 0.6155 - val_loss: 0.6548 - val_accuracy: 0.6411
# Epoch 8/30
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6196 - accuracy: 0.6764 - val_loss: 0.6312 - val_accuracy: 0.7190
# Epoch 9/30
# 313/313 [==============================] - 4s 14ms/step - loss: 0.5866 - accuracy: 0.7484 - val_loss: 0.6044 - val_accuracy: 0.7362
# Epoch 10/30
# 313/313 [==============================] - 3s 8ms/step - loss: 0.5495 - accuracy: 0.7826 - val_loss: 0.5787 - val_accuracy: 0.7466
# Epoch 11/30
# 313/313 [==============================] - 2s 5ms/step - loss: 0.5117 - accuracy: 0.8122 - val_loss: 0.5557 - val_accuracy: 0.7511
# Epoch 12/30
# 313/313 [==============================] - 2s 5ms/step - loss: 0.4760 - accuracy: 0.8273 - val_loss: 0.5366 - val_accuracy: 0.7500
# Epoch 13/30
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4435 - accuracy: 0.8383 - val_loss: 0.5223 - val_accuracy: 0.7489
# Epoch 14/30
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4147 - accuracy: 0.8471 - val_loss: 0.5112 - val_accuracy: 0.7523
# Epoch 15/30
# 313/313 [==============================] - 2s 8ms/step - loss: 0.3896 - accuracy: 0.8522 - val_loss: 0.5034 - val_accuracy: 0.7557
# Epoch 16/30
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3676 - accuracy: 0.8556 - val_loss: 0.4985 - val_accuracy: 0.7557
# Epoch 17/30
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3482 - accuracy: 0.8618 - val_loss: 0.4964 - val_accuracy: 0.7546
# Epoch 18/30
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3311 - accuracy: 0.8678 - val_loss: 0.4965 - val_accuracy: 0.7580
# Epoch 19/30
# 313/313 [==============================] - 2s 5ms/step - loss: 0.3161 - accuracy: 0.8727 - val_loss: 0.4971 - val_accuracy: 0.7546
# Epoch 20/30
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3027 - accuracy: 0.8769 - val_loss: 0.4992 - val_accuracy: 0.7615
# Epoch 21/30
# 313/313 [==============================] - 2s 8ms/step - loss: 0.2904 - accuracy: 0.8813 - val_loss: 0.5030 - val_accuracy: 0.7534
# Epoch 22/30
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2791 - accuracy: 0.8875 - val_loss: 0.5071 - val_accuracy: 0.7557
# Epoch 23/30
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2691 - accuracy: 0.8890 - val_loss: 0.5127 - val_accuracy: 0.7557
# Epoch 24/30
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2598 - accuracy: 0.8883 - val_loss: 0.5184 - val_accuracy: 0.7546
# Epoch 25/30
# 313/313 [==============================] - 2s 5ms/step - loss: 0.2512 - accuracy: 0.8931 - val_loss: 0.5252 - val_accuracy: 0.7546
# Epoch 26/30
# 313/313 [==============================] - 2s 5ms/step - loss: 0.2434 - accuracy: 0.8969 - val_loss: 0.5327 - val_accuracy: 0.7557
# Epoch 27/30
# 313/313 [==============================] - 2s 7ms/step - loss: 0.2360 - accuracy: 0.8981 - val_loss: 0.5406 - val_accuracy: 0.7500
# Epoch 28/30
# 313/313 [==============================] - 3s 8ms/step - loss: 0.2291 - accuracy: 0.9012 - val_loss: 0.5492 - val_accuracy: 0.7431
# Epoch 29/30
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2228 - accuracy: 0.9018 - val_loss: 0.5578 - val_accuracy: 0.7397
# Epoch 30/30
# 313/313 [==============================] - 2s 5ms/step - loss: 0.2168 - accuracy: 0.9061 - val_loss: 0.5671 - val_accuracy: 0.7420
# 1/1 [==============================] - 0s 95ms/step
# I loved this movie
# [0.58947206]
#
#
# that was the worst movie I've ever seen
# [0.02901894]
#
#
# too much violence even for a Bond film
# [0.00443481]
#
#
# a captivating recounting of a cherished myth
# [0.6545394]

# %% [markdown]
# # Use a GRU

# %%
num_epochs = 30

model_gru = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.GRU(32)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

learning_rate = 0.00003 # slower than the default learning rate
model_gru.compile(loss='binary_crossentropy',
                  optimizer=tf.keras.optimizers.Adam(learning_rate),
                  metrics=['accuracy'])

fit_model_and_show_results(model_gru, new_reviews)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 50, 16)            64000
#
#  bidirectional (Bidirectiona  (None, 64)               9600
#  l)
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 73,665
# Trainable params: 73,665
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 313/313 [==============================] - 24s 60ms/step - loss: 0.6892 - accuracy: 0.5590 - val_loss: 0.6927 - val_accuracy: 0.5092
# Epoch 2/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.6864 - accuracy: 0.5590 - val_loss: 0.6931 - val_accuracy: 0.5092
# Epoch 3/30
# 313/313 [==============================] - 6s 19ms/step - loss: 0.6850 - accuracy: 0.5590 - val_loss: 0.6936 - val_accuracy: 0.5092
# Epoch 4/30
# 313/313 [==============================] - 4s 14ms/step - loss: 0.6839 - accuracy: 0.5590 - val_loss: 0.6941 - val_accuracy: 0.5092
# Epoch 5/30
# 313/313 [==============================] - 4s 14ms/step - loss: 0.6825 - accuracy: 0.5590 - val_loss: 0.6945 - val_accuracy: 0.5092
# Epoch 6/30
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6804 - accuracy: 0.5590 - val_loss: 0.6953 - val_accuracy: 0.5092
# Epoch 7/30
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6771 - accuracy: 0.5590 - val_loss: 0.6962 - val_accuracy: 0.5092
# Epoch 8/30
# 313/313 [==============================] - 4s 14ms/step - loss: 0.6716 - accuracy: 0.5596 - val_loss: 0.6991 - val_accuracy: 0.5092
# Epoch 9/30
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6617 - accuracy: 0.5723 - val_loss: 0.7030 - val_accuracy: 0.5092
# Epoch 10/30
# 313/313 [==============================] - 3s 11ms/step - loss: 0.6433 - accuracy: 0.6153 - val_loss: 0.6987 - val_accuracy: 0.5103
# Epoch 11/30
# 313/313 [==============================] - 3s 11ms/step - loss: 0.6098 - accuracy: 0.6499 - val_loss: 0.6299 - val_accuracy: 0.5917
# Epoch 12/30
# 313/313 [==============================] - 4s 13ms/step - loss: 0.5797 - accuracy: 0.6924 - val_loss: 0.6116 - val_accuracy: 0.6617
# Epoch 13/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.5603 - accuracy: 0.7088 - val_loss: 0.6116 - val_accuracy: 0.6950
# Epoch 14/30
# 313/313 [==============================] - 3s 10ms/step - loss: 0.5463 - accuracy: 0.7281 - val_loss: 0.6108 - val_accuracy: 0.6950
# Epoch 15/30
# 313/313 [==============================] - 4s 13ms/step - loss: 0.5295 - accuracy: 0.7374 - val_loss: 0.6095 - val_accuracy: 0.7099
# Epoch 16/30
# 313/313 [==============================] - 3s 11ms/step - loss: 0.5147 - accuracy: 0.7490 - val_loss: 0.5972 - val_accuracy: 0.7133
# Epoch 17/30
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4998 - accuracy: 0.7622 - val_loss: 0.5899 - val_accuracy: 0.7271
# Epoch 18/30
# 313/313 [==============================] - 3s 11ms/step - loss: 0.4835 - accuracy: 0.7747 - val_loss: 0.5906 - val_accuracy: 0.7282
# Epoch 19/30
# 313/313 [==============================] - 4s 12ms/step - loss: 0.4681 - accuracy: 0.7851 - val_loss: 0.5873 - val_accuracy: 0.7339
# Epoch 20/30
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4559 - accuracy: 0.7952 - val_loss: 0.5796 - val_accuracy: 0.7385
# Epoch 21/30
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4436 - accuracy: 0.8044 - val_loss: 0.5715 - val_accuracy: 0.7443
# Epoch 22/30
# 313/313 [==============================] - 3s 11ms/step - loss: 0.4306 - accuracy: 0.8111 - val_loss: 0.5851 - val_accuracy: 0.7477
# Epoch 23/30
# 313/313 [==============================] - 4s 12ms/step - loss: 0.4189 - accuracy: 0.8168 - val_loss: 0.5645 - val_accuracy: 0.7569
# Epoch 24/30
# 313/313 [==============================] - 3s 11ms/step - loss: 0.4093 - accuracy: 0.8214 - val_loss: 0.5900 - val_accuracy: 0.7523
# Epoch 25/30
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4005 - accuracy: 0.8278 - val_loss: 0.5684 - val_accuracy: 0.7615
# Epoch 26/30
# 313/313 [==============================] - 4s 12ms/step - loss: 0.3915 - accuracy: 0.8312 - val_loss: 0.5656 - val_accuracy: 0.7615
# Epoch 27/30
# 313/313 [==============================] - 3s 10ms/step - loss: 0.3827 - accuracy: 0.8376 - val_loss: 0.5935 - val_accuracy: 0.7626
# Epoch 28/30
# 313/313 [==============================] - 3s 11ms/step - loss: 0.3761 - accuracy: 0.8391 - val_loss: 0.5923 - val_accuracy: 0.7706
# Epoch 29/30
# 313/313 [==============================] - 3s 10ms/step - loss: 0.3690 - accuracy: 0.8438 - val_loss: 0.5929 - val_accuracy: 0.7683
# Epoch 30/30
# 313/313 [==============================] - 4s 12ms/step - loss: 0.3619 - accuracy: 0.8447 - val_loss: 0.5900 - val_accuracy: 0.7672
# 1/1 [==============================] - 1s 604ms/step
# I loved this movie
# [0.43827966]
#
#
# that was the worst movie I've ever seen
# [0.13949814]
#
#
# too much violence even for a Bond film
# [0.10138904]
#
#
# a captivating recounting of a cherished myth
# [0.43067232]

# %% [markdown]
# # Add a bidirectional LSTM

# %%
num_epochs = 30

model_bidi_lstm = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(embedding_dim)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

learning_rate = 0.00003
model_bidi_lstm.compile(loss='binary_crossentropy',
                        optimizer=tf.keras.optimizers.Adam(learning_rate),
                        metrics=['accuracy'])
fit_model_and_show_results(model_bidi_lstm, new_reviews)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 50, 16)            64000
#
#  bidirectional_1 (Bidirectio  (None, 32)               4224
#  nal)
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 68,257
# Trainable params: 68,257
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 313/313 [==============================] - 23s 59ms/step - loss: 0.6911 - accuracy: 0.5529 - val_loss: 0.6935 - val_accuracy: 0.5092
# Epoch 2/30
# 313/313 [==============================] - 6s 18ms/step - loss: 0.6870 - accuracy: 0.5590 - val_loss: 0.6954 - val_accuracy: 0.5092
# Epoch 3/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.6841 - accuracy: 0.5590 - val_loss: 0.6991 - val_accuracy: 0.5092
# Epoch 4/30
# 313/313 [==============================] - 4s 11ms/step - loss: 0.6821 - accuracy: 0.5590 - val_loss: 0.7016 - val_accuracy: 0.5092
# Epoch 5/30
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6806 - accuracy: 0.5590 - val_loss: 0.7037 - val_accuracy: 0.5092
# Epoch 6/30
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6788 - accuracy: 0.5590 - val_loss: 0.7057 - val_accuracy: 0.5092
# Epoch 7/30
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6769 - accuracy: 0.5590 - val_loss: 0.7066 - val_accuracy: 0.5092
# Epoch 8/30
# 313/313 [==============================] - 3s 11ms/step - loss: 0.6746 - accuracy: 0.5592 - val_loss: 0.7084 - val_accuracy: 0.5092
# Epoch 9/30
# 313/313 [==============================] - 3s 11ms/step - loss: 0.6718 - accuracy: 0.5632 - val_loss: 0.7090 - val_accuracy: 0.5092
# Epoch 10/30
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6687 - accuracy: 0.5701 - val_loss: 0.7127 - val_accuracy: 0.5092
# Epoch 11/30
# 313/313 [==============================] - 3s 11ms/step - loss: 0.6648 - accuracy: 0.5827 - val_loss: 0.7137 - val_accuracy: 0.5092
# Epoch 12/30
# 313/313 [==============================] - 3s 10ms/step - loss: 0.6602 - accuracy: 0.5976 - val_loss: 0.7170 - val_accuracy: 0.5092
# Epoch 13/30
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6547 - accuracy: 0.6098 - val_loss: 0.7189 - val_accuracy: 0.5092
# Epoch 14/30
# 313/313 [==============================] - 3s 10ms/step - loss: 0.6481 - accuracy: 0.6207 - val_loss: 0.7163 - val_accuracy: 0.5092
# Epoch 15/30
# 313/313 [==============================] - 3s 10ms/step - loss: 0.6401 - accuracy: 0.6380 - val_loss: 0.7148 - val_accuracy: 0.5080
# Epoch 16/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6302 - accuracy: 0.6485 - val_loss: 0.7063 - val_accuracy: 0.5092
# Epoch 17/30
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6180 - accuracy: 0.6675 - val_loss: 0.7003 - val_accuracy: 0.5092
# Epoch 18/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6031 - accuracy: 0.6843 - val_loss: 0.6849 - val_accuracy: 0.5126
# Epoch 19/30
# 313/313 [==============================] - 3s 11ms/step - loss: 0.5857 - accuracy: 0.7033 - val_loss: 0.6556 - val_accuracy: 0.5264
# Epoch 20/30
# 313/313 [==============================] - 3s 11ms/step - loss: 0.5683 - accuracy: 0.7231 - val_loss: 0.6218 - val_accuracy: 0.6365
# Epoch 21/30
# 313/313 [==============================] - 4s 13ms/step - loss: 0.5525 - accuracy: 0.7418 - val_loss: 0.5919 - val_accuracy: 0.7282
# Epoch 22/30
# 313/313 [==============================] - 3s 10ms/step - loss: 0.5384 - accuracy: 0.7601 - val_loss: 0.5713 - val_accuracy: 0.7305
# Epoch 23/30
# 313/313 [==============================] - 3s 10ms/step - loss: 0.5263 - accuracy: 0.7694 - val_loss: 0.5577 - val_accuracy: 0.7408
# Epoch 24/30
# 313/313 [==============================] - 4s 12ms/step - loss: 0.5150 - accuracy: 0.7723 - val_loss: 0.5472 - val_accuracy: 0.7431
# Epoch 25/30
# 313/313 [==============================] - 3s 10ms/step - loss: 0.5037 - accuracy: 0.7808 - val_loss: 0.5373 - val_accuracy: 0.7557
# Epoch 26/30
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4937 - accuracy: 0.7855 - val_loss: 0.5306 - val_accuracy: 0.7592
# Epoch 27/30
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4841 - accuracy: 0.7897 - val_loss: 0.5251 - val_accuracy: 0.7626
# Epoch 28/30
# 313/313 [==============================] - 4s 13ms/step - loss: 0.4745 - accuracy: 0.7957 - val_loss: 0.5209 - val_accuracy: 0.7603
# Epoch 29/30
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4667 - accuracy: 0.8021 - val_loss: 0.5194 - val_accuracy: 0.7592
# Epoch 30/30
# 313/313 [==============================] - 3s 11ms/step - loss: 0.4562 - accuracy: 0.8100 - val_loss: 0.5195 - val_accuracy: 0.7592
# 1/1 [==============================] - 1s 652ms/step
# I loved this movie
# [0.4962854]
#
#
# that was the worst movie I've ever seen
# [0.31462663]
#
#
# too much violence even for a Bond film
# [0.34057963]
#
#
# a captivating recounting of a cherished myth
# [0.5566602]

# %% [markdown]
# # Use multiple bidirectional LSTMs

# %%
num_epochs = 30

model_multiple_bidi_lstm = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(embedding_dim,
                                                       return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(embedding_dim)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

learning_rate = 0.0003
model_multiple_bidi_lstm.compile(loss='binary_crossentropy',
                                 optimizer=tf.keras.optimizers.Adam(learning_rate),
                                 metrics=['accuracy'])
fit_model_and_show_results(model_multiple_bidi_lstm, new_reviews)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 50, 16)            64000
#
#  bidirectional_2 (Bidirectio  (None, 50, 32)           4224
#  nal)
#
#  bidirectional_3 (Bidirectio  (None, 32)               6272
#  nal)
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 74,529
# Trainable params: 74,529
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 313/313 [==============================] - 27s 61ms/step - loss: 0.6838 - accuracy: 0.5565 - val_loss: 0.7263 - val_accuracy: 0.5092
# Epoch 2/30
# 313/313 [==============================] - 8s 24ms/step - loss: 0.5322 - accuracy: 0.7298 - val_loss: 0.6894 - val_accuracy: 0.4966
# Epoch 3/30
# 313/313 [==============================] - 6s 18ms/step - loss: 0.3687 - accuracy: 0.8297 - val_loss: 0.6724 - val_accuracy: 0.5791
# Epoch 4/30
# 313/313 [==============================] - 7s 22ms/step - loss: 0.3087 - accuracy: 0.8595 - val_loss: 0.6681 - val_accuracy: 0.5849
# Epoch 5/30
# 313/313 [==============================] - 6s 18ms/step - loss: 0.2750 - accuracy: 0.8739 - val_loss: 0.6530 - val_accuracy: 0.6388
# Epoch 6/30
# 313/313 [==============================] - 6s 19ms/step - loss: 0.2506 - accuracy: 0.8855 - val_loss: 0.6571 - val_accuracy: 0.5688
# Epoch 7/30
# 313/313 [==============================] - 6s 18ms/step - loss: 0.2383 - accuracy: 0.8916 - val_loss: 0.6411 - val_accuracy: 0.6422
# Epoch 8/30
# 313/313 [==============================] - 6s 18ms/step - loss: 0.2216 - accuracy: 0.9008 - val_loss: 0.7278 - val_accuracy: 0.5241
# Epoch 9/30
# 313/313 [==============================] - 6s 19ms/step - loss: 0.2101 - accuracy: 0.9047 - val_loss: 0.6585 - val_accuracy: 0.6112
# Epoch 10/30
# 313/313 [==============================] - 6s 19ms/step - loss: 0.2021 - accuracy: 0.9092 - val_loss: 0.9155 - val_accuracy: 0.5057
# Epoch 11/30
# 313/313 [==============================] - 5s 16ms/step - loss: 0.1955 - accuracy: 0.9105 - val_loss: 0.7927 - val_accuracy: 0.5264
# Epoch 12/30
# 313/313 [==============================] - 5s 17ms/step - loss: 0.1952 - accuracy: 0.9116 - val_loss: 0.6816 - val_accuracy: 0.5631
# Epoch 13/30
# 313/313 [==============================] - 5s 16ms/step - loss: 0.1839 - accuracy: 0.9176 - val_loss: 0.7038 - val_accuracy: 0.5459
# Epoch 14/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.1784 - accuracy: 0.9170 - val_loss: 0.7142 - val_accuracy: 0.5229
# Epoch 15/30
# 313/313 [==============================] - 6s 18ms/step - loss: 0.1800 - accuracy: 0.9202 - val_loss: 0.6830 - val_accuracy: 0.5665
# Epoch 16/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.1717 - accuracy: 0.9204 - val_loss: 0.7192 - val_accuracy: 0.4943
# Epoch 17/30
# 313/313 [==============================] - 5s 17ms/step - loss: 0.1648 - accuracy: 0.9226 - val_loss: 0.7223 - val_accuracy: 0.4839
# Epoch 18/30
# 313/313 [==============================] - 5s 16ms/step - loss: 0.1652 - accuracy: 0.9209 - val_loss: 0.7233 - val_accuracy: 0.4931
# Epoch 19/30
# 313/313 [==============================] - 5s 17ms/step - loss: 0.1638 - accuracy: 0.9247 - val_loss: 0.7374 - val_accuracy: 0.4644
# Epoch 20/30
# 313/313 [==============================] - 5s 17ms/step - loss: 0.1607 - accuracy: 0.9264 - val_loss: 0.7388 - val_accuracy: 0.5183
# Epoch 21/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.1569 - accuracy: 0.9239 - val_loss: 0.8155 - val_accuracy: 0.5161
# Epoch 22/30
# 313/313 [==============================] - 6s 18ms/step - loss: 0.1560 - accuracy: 0.9271 - val_loss: 0.7691 - val_accuracy: 0.4989
# Epoch 23/30
# 313/313 [==============================] - 5s 17ms/step - loss: 0.1533 - accuracy: 0.9276 - val_loss: 0.8012 - val_accuracy: 0.5115
# Epoch 24/30
# 313/313 [==============================] - 6s 18ms/step - loss: 0.1519 - accuracy: 0.9266 - val_loss: 0.8466 - val_accuracy: 0.5057
# Epoch 25/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.1451 - accuracy: 0.9283 - val_loss: 0.8497 - val_accuracy: 0.4817
# Epoch 26/30
# 313/313 [==============================] - 5s 16ms/step - loss: 0.1434 - accuracy: 0.9266 - val_loss: 0.8684 - val_accuracy: 0.4943
# Epoch 27/30
# 313/313 [==============================] - 5s 17ms/step - loss: 0.1395 - accuracy: 0.9301 - val_loss: 0.9069 - val_accuracy: 0.4920
# Epoch 28/30
# 313/313 [==============================] - 5s 16ms/step - loss: 0.1413 - accuracy: 0.9299 - val_loss: 0.9136 - val_accuracy: 0.5780
# Epoch 29/30
# 313/313 [==============================] - 6s 18ms/step - loss: 0.1366 - accuracy: 0.9304 - val_loss: 0.8818 - val_accuracy: 0.5206
# Epoch 30/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.1376 - accuracy: 0.9314 - val_loss: 0.9504 - val_accuracy: 0.5654
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f909345a4d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 1s/step
# I loved this movie
# [0.5322359]
#
#
# that was the worst movie I've ever seen
# [0.07117564]
#
#
# too much violence even for a Bond film
# [0.0046663]
#
#
# a captivating recounting of a cherished myth
# [0.9972154]

# %% [markdown]
# # Try some more reviews

# %%
# Write some new reviews

review1 = """I loved this movie"""

review2 = """that was the worst movie I've ever seen"""

review3 = """too much violence even for a Bond film"""

review4 = """a captivating recounting of a cherished myth"""

review5 = """I saw this movie yesterday and I was feeling low to start with,
 but it was such a wonderful movie that it lifted my spirits and brightened
 my day, you can\'t go wrong with a movie with Whoopi Goldberg in it."""

review6 = """I don\'t understand why it received an oscar recommendation
 for best movie, it was long and boring"""

review7 = """the scenery was magnificent, the CGI of the dogs was so realistic I
 thought they were played by real dogs even though they talked!"""

review8 = """The ending was so sad and yet so uplifting at the same time.
 I'm looking for an excuse to see it again"""

review9 = """I had expected so much more from a movie made by the director
 who made my most favorite movie ever, I was very disappointed in the tedious
 story"""

review10 = "I wish I could watch this movie every day for the rest of my life"

more_reviews = [review1, review2, review3, review4, review5, review6, review7,
               review8, review9, review10]

# %%
print("============================\n","Embeddings only:\n", "============================")
predict_review(model, more_reviews)
# Out:
# ============================
#  Embeddings only:
#  ============================
# 1/1 [==============================] - 0s 21ms/step
# I loved this movie
# [0.3941081]
#
#
# that was the worst movie I've ever seen
# [0.11844173]
#
#
# too much violence even for a Bond film
# [0.0325942]
#
#
# a captivating recounting of a cherished myth
# [0.6168419]
#
#
# I saw this movie yesterday and I was feeling low to start with,
#  but it was such a wonderful movie that it lifted my spirits and brightened
#  my day, you can't go wrong with a movie with Whoopi Goldberg in it.
# [0.29064378]
#
#
# I don't understand why it received an oscar recommendation
#  for best movie, it was long and boring
# [0.48133057]
#
#
# the scenery was magnificent, the CGI of the dogs was so realistic I
#  thought they were played by real dogs even though they talked!
# [0.26605204]
#
#
# The ending was so sad and yet so uplifting at the same time.
#  I'm looking for an excuse to see it again
# [0.50748384]
#
#
# I had expected so much more from a movie made by the director
#  who made my most favorite movie ever, I was very disappointed in the tedious
#  story
# [0.01116488]
#
#
# I wish I could watch this movie every day for the rest of my life
# [0.3007552]

# %%
print("============================\n","With CNN\n", "============================")
predict_review(model_cnn, more_reviews)
# Out:
# ============================
#  With CNN
#  ============================
# 1/1 [==============================] - 0s 49ms/step
# I loved this movie
# [0.58947206]
#
#
# that was the worst movie I've ever seen
# [0.02901894]
#
#
# too much violence even for a Bond film
# [0.00443481]
#
#
# a captivating recounting of a cherished myth
# [0.6545394]
#
#
# I saw this movie yesterday and I was feeling low to start with,
#  but it was such a wonderful movie that it lifted my spirits and brightened
#  my day, you can't go wrong with a movie with Whoopi Goldberg in it.
# [0.8886136]
#
#
# I don't understand why it received an oscar recommendation
#  for best movie, it was long and boring
# [0.93414176]
#
#
# the scenery was magnificent, the CGI of the dogs was so realistic I
#  thought they were played by real dogs even though they talked!
# [0.7177404]
#
#
# The ending was so sad and yet so uplifting at the same time.
#  I'm looking for an excuse to see it again
# [0.47439203]
#
#
# I had expected so much more from a movie made by the director
#  who made my most favorite movie ever, I was very disappointed in the tedious
#  story
# [0.04913296]
#
#
# I wish I could watch this movie every day for the rest of my life
# [0.09446329]

# %%
print("===========================\n","With bidirectional GRU\n", "============================")
predict_review(model_gru, more_reviews)
# Out:
# ===========================
#  With bidirectional GRU
#  ============================
# 1/1 [==============================] - 0s 21ms/step
# I loved this movie
# [0.43827966]
#
#
# that was the worst movie I've ever seen
# [0.13949814]
#
#
# too much violence even for a Bond film
# [0.10138904]
#
#
# a captivating recounting of a cherished myth
# [0.43067232]
#
#
# I saw this movie yesterday and I was feeling low to start with,
#  but it was such a wonderful movie that it lifted my spirits and brightened
#  my day, you can't go wrong with a movie with Whoopi Goldberg in it.
# [0.09251807]
#
#
# I don't understand why it received an oscar recommendation
#  for best movie, it was long and boring
# [0.19937623]
#
#
# the scenery was magnificent, the CGI of the dogs was so realistic I
#  thought they were played by real dogs even though they talked!
# [0.07252369]
#
#
# The ending was so sad and yet so uplifting at the same time.
#  I'm looking for an excuse to see it again
# [0.16485667]
#
#
# I had expected so much more from a movie made by the director
#  who made my most favorite movie ever, I was very disappointed in the tedious
#  story
# [0.05501766]
#
#
# I wish I could watch this movie every day for the rest of my life
# [0.23131625]

# %%
print("===========================\n", "With a single bidirectional LSTM:\n", "===========================")
predict_review(model_bidi_lstm, more_reviews)
# Out:
# ===========================
#  With a single bidirectional LSTM:
#  ===========================
# 1/1 [==============================] - 0s 21ms/step
# I loved this movie
# [0.4962854]
#
#
# that was the worst movie I've ever seen
# [0.31462663]
#
#
# too much violence even for a Bond film
# [0.34057963]
#
#
# a captivating recounting of a cherished myth
# [0.5566602]
#
#
# I saw this movie yesterday and I was feeling low to start with,
#  but it was such a wonderful movie that it lifted my spirits and brightened
#  my day, you can't go wrong with a movie with Whoopi Goldberg in it.
# [0.23511872]
#
#
# I don't understand why it received an oscar recommendation
#  for best movie, it was long and boring
# [0.24116167]
#
#
# the scenery was magnificent, the CGI of the dogs was so realistic I
#  thought they were played by real dogs even though they talked!
# [0.23855893]
#
#
# The ending was so sad and yet so uplifting at the same time.
#  I'm looking for an excuse to see it again
# [0.44300723]
#
#
# I had expected so much more from a movie made by the director
#  who made my most favorite movie ever, I was very disappointed in the tedious
#  story
# [0.17344745]
#
#
# I wish I could watch this movie every day for the rest of my life
# [0.47177306]

# %%
print("===========================\n", "With multiple bidirectional LSTM:\n", "==========================")
predict_review(model_multiple_bidi_lstm, more_reviews)
# Out:
# ===========================
#  With multiple bidirectional LSTM:
#  ==========================
# 1/1 [==============================] - 0s 23ms/step
# I loved this movie
# [0.5322359]
#
#
# that was the worst movie I've ever seen
# [0.07117564]
#
#
# too much violence even for a Bond film
# [0.0046663]
#
#
# a captivating recounting of a cherished myth
# [0.9972154]
#
#
# I saw this movie yesterday and I was feeling low to start with,
#  but it was such a wonderful movie that it lifted my spirits and brightened
#  my day, you can't go wrong with a movie with Whoopi Goldberg in it.
# [0.24544956]
#
#
# I don't understand why it received an oscar recommendation
#  for best movie, it was long and boring
# [0.99430335]
#
#
# the scenery was magnificent, the CGI of the dogs was so realistic I
#  thought they were played by real dogs even though they talked!
# [0.9976787]
#
#
# The ending was so sad and yet so uplifting at the same time.
#  I'm looking for an excuse to see it again
# [0.90910596]
#
#
# I had expected so much more from a movie made by the director
#  who made my most favorite movie ever, I was very disappointed in the tedious
#  story
# [0.00347999]
#
#
# I wish I could watch this movie every day for the rest of my life
# [0.02461313]
